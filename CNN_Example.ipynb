# %%
import pandas as pd

DATA_SET_FILE = './labeled_news.csv'

df = pd.read_csv(DATA_SET_FILE)

df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ba635b828>]], dtype=object)

# %%
import matplotlib.pyplot as plt

plt.style.use = 'default'
# class distribution bar
df['category'].value_counts().plot(kind='bar')

# %%
# source distribution bar
df['source'].value_counts().plot(kind='bar')

# %%
# An example to use VocabularyProcessor to convert words to numbers
import numpy as np
import tensorflow as tf

# max length of sentence taken into consideration
MAX_DOCUMENT_LENGTH = 5

vocab_processor = tf.contrib.learn.preprocessing.VocabularyProcessor(MAX_DOCUMENT_LENGTH)
